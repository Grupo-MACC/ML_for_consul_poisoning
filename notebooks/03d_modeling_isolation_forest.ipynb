# %% [markdown]
# # 03_Modeling

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import roc_auc_score, average_precision_score
import joblib
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('../data/processed/windowed_dataset_cleaned.csv')

X = df.drop(columns=['is_attack'])
y = df['is_attack']

# %% [markdown]
# ### Data Split

# %% [markdown]
# The approach here is to train the model with normal traffic only. The test set is the concatenation of every labeled attack and 5% of the legitimate traffic. This will help analyzing false positives.

# %%
# ======================
# Split normal traffic
# ======================
df_normal = df[df['is_attack'] == 0]
df_attack = df[df['is_attack'] == 1]

X_normal = df_normal.drop(columns=['is_attack'])
X_attack = df_attack.drop(columns=['is_attack'])

X_normal_train, X_normal_test = train_test_split(
    X_normal,
    test_size=0.05,
    random_state=42
)

# ======================
# Build test set
# ======================
X_test = pd.concat([X_normal_test, X_attack], axis=0)
y_test = pd.Series(
    np.concatenate([
        np.zeros(len(X_normal_test)),
        np.ones(len(X_attack))
    ]),
    index=X_test.index
)
print(y_test.describe())
# Out:
# count    1529.000000
# mean        0.226292
# std         0.418567
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# dtype: float64

# %% [markdown]
# ## Modeling

# %%
contamination = y.mean()
print(f"Contamination (proporción de ataques): {contamination:.4f}")
from sklearn.ensemble import IsolationForest

from sklearn.pipeline import Pipeline
model = Pipeline([
    ('scaler', RobustScaler()),  # Escala a media=0, std=1
    ('if', IsolationForest(
        n_estimators=100,
        contamination='auto', # 0.001
        max_samples='auto', # number of samples to draw from X to train each base estimator
        random_state=42,
        n_jobs=-1 # usar todos los núcleos disponibles
    ))
])

model.fit(X_normal_train)
# Out:
# Contamination (proporción de ataques): 0.0144
# Pipeline(steps=[('scaler', RobustScaler()),
#                 ('if', IsolationForest(n_jobs=-1, random_state=42))])

# %% [markdown]
# Isolation forest is based on underlying Random Decision Trees that are going to isolate each sample from the rest of samples. The easier it is to isolate the sample the high anomaly score it will get.
#
# - The **n_estimator** is the number of decision trees that are going to be used. The default value was chosen.
# - The main hyperparameter of this model is **contamination**. This parameters define where is going to put the threshold the model to tell if a sample is an anomaly or not. It won't influence its training or the anomaly score it is going to give to each sample. We decides to put the proportion of attacks the data has to see if it if able to find them within the data

# %%
anomaly_score = -model.score_samples(X_test)
anomaly_label = model.predict(X_test) == -1
roc_auc = roc_auc_score(y_test, anomaly_score)
ap = average_precision_score(y_test, anomaly_score)
print(f"ROC AUC: {roc_auc:.4f}")
print(f"Average Precision: {ap:.4f}")

df_test = X_test.copy()
df_test['is_attack'] = y_test.values
df_test['anomaly_score'] = anomaly_score
df_test['anomaly_label'] = np.where(anomaly_label, 'Anomaly', 'Normal')
# Out:
# ROC AUC: 0.9990
# Average Precision: 0.9969

# %% [markdown]
# - These metric show that the model captures nearly every attack

# %% [markdown]
# ## Visualize results

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
import plotly.express as px

# -----------------------------
# PCA pipeline (visualización)
# -----------------------------
pca_pipeline = Pipeline([
    ('scaler', RobustScaler()),
    ('pca', PCA(n_components=2, random_state=42))
])

X_pca = pca_pipeline.fit_transform(df_test.drop(columns=[
    'is_attack', 'anomaly_score', 'anomaly_label'
]))

print("Varianza explicada por componente:")
print(pca_pipeline['pca'].explained_variance_ratio_)
print("Varianza total explicada:",
      pca_pipeline['pca'].explained_variance_ratio_.sum())

# DataFrame para plot
df_pca_vis = pd.DataFrame({
    'PCA1': X_pca[:, 0],
    'PCA2': X_pca[:, 1],
    'anomaly_label': df_test['anomaly_label'].values,
    'is_attack': df_test['is_attack'].values
})

# Plot
fig = px.scatter(
    df_pca_vis,
    x='PCA1',
    y='PCA2',
    color='anomaly_label',
    symbol='is_attack',
    title="PCA (2D) – Isolation Forest (trained on normal only)",
    width=900,
    height=700,
    color_discrete_map={'Anomaly': 'red', 'Normal': 'blue'}
)

fig.update_traces(marker=dict(size=6, opacity=0.8))
fig.update_layout(legend_title_text='Predicted label')
fig.show()
# Out:
# Varianza explicada por componente:
# [0.96504869 0.0184853 ]
# Varianza total explicada: 0.9835339925078223

# %%
import umap

# -----------------------------
# UMAP pipeline
# -----------------------------
umap_pipeline = Pipeline([
    ('scaler', RobustScaler()),
    ('umap', umap.UMAP(
        n_neighbors=30,
        min_dist=0.1,
        n_components=2,
        random_state=42
    ))
])

X_umap = umap_pipeline.fit_transform(
    df_test.drop(columns=[
        'is_attack', 'anomaly_score', 'anomaly_label'
    ])
)

# DataFrame base
df_umap = pd.DataFrame({
    'UMAP1': X_umap[:, 0],
    'UMAP2': X_umap[:, 1],
    'anomaly_score': df_test['anomaly_score'].values,
    'anomaly_label': df_test['anomaly_label'].values,
    'is_attack': df_test['is_attack'].values
})
feature_cols = [
    'conn_count_10s_max',
    'burst_score_max',
    'bytes_ratio_mean',
    'recent_activity_score_std'
]

df_umap = pd.concat(
    [df_umap, df_test[feature_cols].reset_index(drop=True)],
    axis=1
)

fig = px.scatter(
    df_umap,
    x='UMAP1',
    y='UMAP2',
    color='anomaly_score',
    color_continuous_scale='viridis',
    hover_data=feature_cols + ['is_attack'],
    title="UMAP – colored by anomaly score (test set)",
    width=900,
    height=700
)

fig.update_traces(marker=dict(size=6, opacity=0.8))
fig.show()
# Out:
# /Users/taxi/miniconda3/envs/consoning/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
df_all = df.copy()

# Inicializar columnas
df_all['split'] = 'train'
df_all['anomaly_score'] = np.nan
df_all['anomaly_label'] = 'Normal'

# Marcar test
df_all.loc[X_test.index, 'split'] = 'test'
df_all.loc[X_test.index, 'anomaly_score'] = anomaly_score
df_all.loc[X_test.index, 'anomaly_label'] = np.where(anomaly_label, 'Anomaly', 'Normal')

import umap
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler

feature_cols = df.columns.difference(['is_attack'])

umap_pipeline = Pipeline([
    ('scaler', RobustScaler()),
    ('umap', umap.UMAP(
        n_neighbors=30,
        min_dist=0.1,
        n_components=2,
        random_state=42
    ))
])

X_umap_all = umap_pipeline.fit_transform(df_all[feature_cols])

df_all['UMAP1'] = X_umap_all[:, 0]
df_all['UMAP2'] = X_umap_all[:, 1]

import plotly.express as px

fig = px.scatter(
    df_all,
    x='UMAP1',
    y='UMAP2',
    color='anomaly_score',
    symbol='split',
    symbol_map={'train': 'circle', 'test': 'diamond'},
    title="UMAP – All data (train vs test highlighted)",
    width=1000,
    height=800,
    hover_data=['is_attack', 'split'],
    color_continuous_scale='viridis'
)

# Tamaño diferente
fig.update_traces(
    marker=dict(
        opacity=0.8,
        size=6
    ),
    selector=dict(name='train')
)

fig.update_traces(
    marker=dict(
        opacity=1.0,
        size=9,
        line=dict(width=1, color='black')
    ),
    selector=dict(name='test')
)

fig.show()
# Out:
# /Users/taxi/miniconda3/envs/consoning/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#
# /Users/taxi/miniconda3/envs/consoning/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:324: UserWarning:
#
# Graph is not fully connected, spectral embedding may not work as expected.

# %%
import plotly.express as px

# Asumimos que:
# - df['anomaly_score'] contiene los scores de anomalía
# - y son las etiquetas reales (0 = Normal, 1 = Anomaly)

# Crear una copia temporal para facilitar el plotting
plot_df = df.copy()
plot_df['True Label'] = y
plot_df['True Label'] = plot_df['True Label'].map({0: 'Normal (0)', 1: 'Attack (1)'})

# Crear histograma con KDE aproximado (Plotly no tiene KDE nativo, pero puedes usar marginal='violin' o suavizado visual)
fig = px.histogram(
    plot_df,
    x=df['anomaly_score'],
    color='True Label',
    nbins=50,
    opacity=0.6,
    histnorm='',  # usa conteo absoluto (como en sns.histplot sin stat=...)
    color_discrete_map={'Normal (0)': 'skyblue', 'Attack (1)': 'salmon'},
    marginal=None,  # opcional: puedes poner 'rug' o 'box' si quieres
    title='Distribution of Anomaly Score'
)

# Actualizar diseño
fig.update_layout(
    xaxis_title='Anomaly Score',
    yaxis_title='Count',
    legend_title='True Label',
    font=dict(size=14),
    width=700,
    height=500
)

# Opcional: añadir curvas suaves (KDE-like) usando líneas (requiere scipy)
# Pero si solo quieres el histograma como en tu ejemplo, esto es suficiente.

fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/consoning/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'anomaly_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 15
#      10 plot_df['True Label'] = plot_df['True Label'].map({0: 'Normal (0)', 1: 'Attack (1)'})
#      12 # Crear histograma con KDE aproximado (Plotly no tiene KDE nativo, pero puedes usar marginal='violin' o suavizado visual)
#      13 fig = px.histogram(
#      14     plot_df,
# ---> 15     x=df['anomaly_score'],
#      16     color='True Label',
#      17     nbins=50,
#      18     opacity=0.6,
#      19     histnorm='',  # usa conteo absoluto (como en sns.histplot sin stat=...)
#      20     color_discrete_map={'Normal (0)': 'skyblue', 'Attack (1)': 'salmon'},
#      21     marginal=None,  # opcional: puedes poner 'rug' o 'box' si quieres
#      22     title='Distribution of Anomaly Score'
#      23 )
#      25 # Actualizar diseño
#      26 fig.update_layout(
#      27     xaxis_title='Anomaly Score',
#      28     yaxis_title='Count',
#    (...)     32     height=500
#      33 )
#
# File ~/miniconda3/envs/consoning/lib/python3.11/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/miniconda3/envs/consoning/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'anomaly_score'

# %% [markdown]
# - The model gives to each sample an anomaly score. The samples central cluster have a low anomaly score with means that are difficult to separe from the rest of the samples.
# - The island on the right is formed by a mid anomaly score which suggests that those samples are easier to isolate than the previous ones. As we have seen previously, those sample have a higher network intesity, connexions, etc. (try hover on those samples)
# - If we zoom in the bottom right corner, we can see that there are two long islands and the model is actually able to make a difference between them in terms of anomaly score, both been more anomalous than the rest.

# %% [markdown]
# ## Save Model

# %%
joblib.dump(model, "../models/isolation_forest_model.joblib")
# Out:
# ['../models/isolation_forest_model.joblib']
